# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('/content/ResaleFlatPricesBasedonApprovalDate19901999.csv')

# %%
df1
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 287191  1999-12      YISHUN  EXECUTIVE   611      YISHUN ST 61     10 TO 12
# 287192  1999-12      YISHUN  EXECUTIVE   324       YISHUN CTRL     01 TO 03
# 287193  1999-12      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 287194  1999-12      YISHUN  EXECUTIVE   356    YISHUN RING RD     04 TO 06
# 287195  1999-12      YISHUN  EXECUTIVE   358    YISHUN RING RD     01 TO 03
#
# ...

# %%
df2 = pd.read_csv('/content/ResaleFlatPricesBasedonApprovalDate2000Feb2012 (1).csv')
df2
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       2000-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1       2000-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2       2000-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3       2000-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4       2000-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...         ...         ...        ...   ...               ...          ...
# 369646  2012-02      YISHUN     5 ROOM   212      YISHUN ST 21     10 TO 12
# 369647  2012-02      YISHUN     5 ROOM   758      YISHUN ST 72     01 TO 03
# 369648  2012-02      YISHUN     5 ROOM   873      YISHUN ST 81     01 TO 03
# 369649  2012-02      YISHUN  EXECUTIVE   664      YISHUN AVE 4     07 TO 09
# 369650  2012-02      YISHUN  EXECUTIVE   293      YISHUN ST 22     04 TO 06
#
# ...

# %%
df3 = pd.read_csv('/content/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014 (1).csv')
df3
# Out:
#          month        town  flat_type block        street_name storey_range  \
# 0      2012-03  ANG MO KIO     2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1      2012-03  ANG MO KIO     2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2      2012-03  ANG MO KIO     3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3      2012-03  ANG MO KIO     3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4      2012-03  ANG MO KIO     3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
# ...        ...         ...        ...   ...                ...          ...
# 52198  2014-12      YISHUN     5 ROOM   816       YISHUN ST 81     10 TO 12
# 52199  2014-12      YISHUN  EXECUTIVE   325        YISHUN CTRL     10 TO 12
# 52200  2014-12      YISHUN  EXECUTIVE   618     YISHUN RING RD     07 TO 09
# 52201  2014-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     07 TO 09
# 52202  2014-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     04 TO 06
#
# ...

# %%
df4 = pd.read_csv('/content/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016 (1).csv')
df4
# Out:
#          month        town         flat_type block        street_name  \
# 0      2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1      2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2      2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3      2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4      2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...        ...         ...               ...   ...                ...
# 37148  2016-12      YISHUN            5 ROOM   297       YISHUN ST 20
# 37149  2016-12      YISHUN            5 ROOM   838       YISHUN ST 81
# 37150  2016-12      YISHUN         EXECUTIVE   664       YISHUN AVE 4
# 37151  2016-12      YISHUN         EXECUTIVE   325        YISHUN CTRL
# 37152  2016-12      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df5 = pd.read_csv('/content/ResaleflatpricesbasedonregistrationdatefromJan2017onwards (2).csv')
df5
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 175591  2024-03      YISHUN  EXECUTIVE   791       YISHUN AVE 2     10 TO 12
# 175592  2024-03      YISHUN  EXECUTIVE   392       YISHUN AVE 6     07 TO 09
# 175593  2024-03      YISHUN  EXECUTIVE   326     YISHUN RING RD     10 TO 12
# 175594  2024-03      YISHUN  EXECUTIVE   360     YISHUN RING RD     04 TO 06
# 175595  2024-03      YISHUN  EXECUTIVE   606       YISHUN ST 61     07 TO 09
#
# ...

# %%
df = pd.concat([df1,df2,df3,df4,df5],ignore_index= True)
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 921794  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 921795  2024-03      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 921796  2024-03      YISHUN  EXECUTIVE   326    YISHUN RING RD     10 TO 12
# 921797  2024-03      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 921798  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %% [markdown]
# **Datatypes of this dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921799 entries, 0 to 921798
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                921799 non-null  object
#  1   town                 921799 non-null  object
#  2   flat_type            921799 non-null  object
#  3   block                921799 non-null  object
#  4   street_name          921799 non-null  object
#  5   storey_range         921799 non-null  object
#  6   floor_area_sqm       921799 non-null  float64
#  7   flat_model           921799 non-null  object
#  8   lease_commence_date  921799 non-null  int64
#  9   resale_price         921799 non-null  float64
#  10  remaining_lease      212749 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.4+ MB

# %%
def convert_to_years(row):
    if pd.notna(row) and isinstance(row, str):
        if 'years' in row:
            parts = row.split()
            years = float(parts[0])
            months = float(parts[2]) if len(parts) > 2 else 0
            return years + months / 12
    return row

# %%
df['remaining_lease'] =df['remaining_lease'].apply(convert_to_years)

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 921794  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 921795  2024-03      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 921796  2024-03      YISHUN  EXECUTIVE   326    YISHUN RING RD     10 TO 12
# 921797  2024-03      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 921798  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
df[['resale_year','resale_month']] = df['month'].str.split('-',expand=True)

# %%
df.drop('month',axis = 1,inplace = True)

# %%
df.head(2)
# Out:
#          town flat_type block       street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12            31.0
# 1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06            31.0
#
#   flat_model  lease_commence_date  resale_price  remaining_lease resale_year  \
# 0   IMPROVED                 1977        9000.0              NaN        1990
# 1   IMPROVED                 1977        6000.0              NaN        1990
#
#   resale_month
# 0           01
# 1           01

# %%
# CONVERTING

df['block'] = pd.to_numeric(df['block'], errors='coerce')
df['resale_year'] = pd.to_numeric(df['resale_year'], errors='coerce')
df['resale_month'] = pd.to_numeric(df['resale_month'], errors='coerce')
df['block'] = df['block'].fillna(df['block'].mode()[0])

# %%
df
# Out:
#               town  flat_type  block       street_name storey_range  \
# 0       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12
# 1       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     04 TO 06
# 2       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12
# 3       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     07 TO 09
# 4       ANG MO KIO     3 ROOM  216.0  ANG MO KIO AVE 1     04 TO 06
# ...            ...        ...    ...               ...          ...
# 921794      YISHUN  EXECUTIVE  791.0      YISHUN AVE 2     10 TO 12
# 921795      YISHUN  EXECUTIVE  392.0      YISHUN AVE 6     07 TO 09
# 921796      YISHUN  EXECUTIVE  326.0    YISHUN RING RD     10 TO 12
# 921797      YISHUN  EXECUTIVE  360.0    YISHUN RING RD     04 TO 06
# 921798      YISHUN  EXECUTIVE  606.0      YISHUN ST 61     07 TO 09
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# ...

# %% [markdown]
# **Checking Null values**

# %%
df.isnull().sum()
# Out:
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# resale_year                 0
# resale_month                0
# dtype: int64

# %%
df.describe()
# Out:
#                block  floor_area_sqm  lease_commence_date  resale_price  \
# count  921799.000000   921799.000000        921799.000000  9.217990e+05
# mean      293.174566       95.694443          1988.219093  3.191383e+05
# std       262.563923       25.835508            10.604120  1.690285e+05
# min         1.000000       28.000000          1966.000000  5.000000e+03
# 25%        57.000000       73.000000          1981.000000  1.925000e+05
# 50%       224.000000       93.000000          1986.000000  2.950000e+05
# 75%       484.000000      113.000000          1996.000000  4.150000e+05
# max       980.000000      307.000000          2022.000000  1.568888e+06
#
#        remaining_lease    resale_year   resale_month
# count    212749.000000  921799.000000  921799.000000
# mean         74.523389    2006.064816       6.562942
# std          13.432559       9.247721       3.419372
# min          41.750000    1990.000000       1.000000
# ...

# %%
df.corr(numeric_only= True)
# Out:
#                         block  floor_area_sqm  lease_commence_date  \
# block                1.000000        0.187564             0.008841
# floor_area_sqm       0.187564        1.000000             0.389678
# lease_commence_date  0.008841        0.389678             1.000000
# resale_price        -0.085927        0.566242             0.536648
# remaining_lease     -0.290371        0.161756             0.983276
# resale_year         -0.114454        0.064185             0.429469
# resale_month         0.001136        0.002905             0.006809
#
#                      resale_price  remaining_lease  resale_year  resale_month
# block                   -0.085927        -0.290371    -0.114454      0.001136
# floor_area_sqm           0.566242         0.161756     0.064185      0.002905
# lease_commence_date      0.536648         0.983276     0.429469      0.006809
# resale_price             1.000000         0.328577     0.671178      0.010224
# ...

# %%
dataframe = df.copy()

# %%
dataframe
# Out:
#               town  flat_type  block       street_name storey_range  \
# 0       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12
# 1       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     04 TO 06
# 2       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12
# 3       ANG MO KIO     1 ROOM  309.0  ANG MO KIO AVE 1     07 TO 09
# 4       ANG MO KIO     3 ROOM  216.0  ANG MO KIO AVE 1     04 TO 06
# ...            ...        ...    ...               ...          ...
# 921794      YISHUN  EXECUTIVE  791.0      YISHUN AVE 2     10 TO 12
# 921795      YISHUN  EXECUTIVE  392.0      YISHUN AVE 6     07 TO 09
# 921796      YISHUN  EXECUTIVE  326.0    YISHUN RING RD     10 TO 12
# 921797      YISHUN  EXECUTIVE  360.0    YISHUN RING RD     04 TO 06
# 921798      YISHUN  EXECUTIVE  606.0      YISHUN ST 61     07 TO 09
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# ...

# %%
dataframe.remaining_lease.fillna(dataframe.remaining_lease.median(),inplace = True)

# %%
dataframe.head(3)
# Out:
#          town flat_type  block       street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12            31.0
# 1  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     04 TO 06            31.0
# 2  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12            31.0
#
#   flat_model  lease_commence_date  resale_price  remaining_lease  resale_year  \
# 0   IMPROVED                 1977        9000.0            74.25         1990
# 1   IMPROVED                 1977        6000.0            74.25         1990
# 2   IMPROVED                 1977        8000.0            74.25         1990
#
#    resale_month
# 0             1
# 1             1
# 2             1

# %% [markdown]
# **Checking Duplicates value**

# %%
dataframe.duplicated().sum()
# Out:
# 2334

# %%
dataframe.drop_duplicates(inplace = True)

# %%
dataframe.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Types of features**

# %%
num_features = [feature for feature in dataframe.columns if dataframe[feature].dtype != 'O']
print('Number of Numerical Features :',len(num_features))
# Out:
# Number of Numerical Features : 7

# %%
cat_features = [feature for feature in dataframe.columns if dataframe[feature].dtype == 'O']
print('Number of Categorical Features :',len(cat_features))
# Out:
# Number of Categorical Features : 5

# %%
discrete_features = [feature for feature in num_features if len(dataframe[feature].unique())<=25]
print('Number of Discrete Features :',len(discrete_features))
# Out:
# Number of Discrete Features : 1

# %%
continuous_features = [feature for feature in num_features if feature not in discrete_features]
print('Number of Continuous features:',len(continuous_features))
# Out:
# Number of Continuous features: 6

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def compute_vif(df,considered_features):
  X = df[considered_features]
  X['intercept'] = 1
  vif = pd.DataFrame()
  vif['variable'] = X.columns
  vif['VIF'] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
  vif =vif[vif['variable']!= 'intercept']
  return vif

# %%
compute_vif(dataframe,num_features)
# Out:
#               variable       VIF
# 0                block  1.142024
# 1       floor_area_sqm  2.491668
# 2  lease_commence_date  2.957614
# 3         resale_price  3.981570
# 4      remaining_lease  2.132652
# 5          resale_year  3.089552
# 6         resale_month  1.002686

# %% [markdown]
# There is no relation to relation to the dataset.

# %% [markdown]
# **Checking Outlier**

# %%
for i in continuous_features:
  plt.figure(figsize = (10,5))
  plt.title(str(i))
  sns.set_style('ticks')
  ax = sns.boxplot(dataframe[i])

# %%
def detect_outliers(col):
  # Finding the outlier
  percentile25 = dataframe[col].quantile(0.25)
  percentile75 = dataframe[col].quantile(0.75)
  print('\n ####',col,'####')
  print('percentile25',percentile25)
  print('percentile75',percentile75)
  iqr = percentile75 - percentile25
  upper_limit = percentile75 + 3 * iqr
  lower_limit = percentile25 - 3 * iqr
  print('Upper limit',upper_limit)
  print('Lower limit',lower_limit)
  dataframe.loc[(dataframe[col]>upper_limit),col] = upper_limit
  dataframe.loc[(dataframe[col]<lower_limit),col] = lower_limit
  return dataframe

# %%
for col in num_features:
  detect_outliers(col)
# Out:
#  #### block ####
# percentile25 57.0
# percentile75 484.0
# Upper limit 1765.0
# Lower limit -1224.0
#
#  #### floor_area_sqm ####
# percentile25 73.0
# percentile75 113.0
# Upper limit 233.0
# Lower limit -47.0
#
#  #### lease_commence_date ####
# percentile25 1981.0
# percentile75 1996.0
# Upper limit 2041.0
# Lower limit 1936.0
#
#  #### resale_price ####
# percentile25 193000.0
# percentile75 415000.0
# Upper limit 1081000.0
# Lower limit -473000.0
#
#  #### remaining_lease ####
# percentile25 74.25
# percentile75 74.25
# Upper limit 74.25
# Lower limit 74.25
#
#  #### resale_year ####
# percentile25 1999.0
# percentile75 2013.0
# Upper limit 2055.0
# Lower limit 1957.0
#
#  #### resale_month ####
# percentile25 4.0
# percentile75 10.0
# Upper limit 28.0
# Lower limit -14.0

# %%
dataframe [num_features].skew(axis = 0,skipna = True)
# Out:
# block                  0.685779
# floor_area_sqm         0.361951
# lease_commence_date    0.639134
# resale_price           0.905542
# remaining_lease        0.000000
# resale_year            0.295569
# resale_month          -0.036760
# dtype: float64

# %%
dataframe.drop('remaining_lease',axis = 1,inplace = True)

# %% [markdown]
# Remaining_lease and lease commence date are highly correlated so that i drop the features.

# %%
dataframe.head()
# Out:
#          town flat_type  block       street_name storey_range  floor_area_sqm  \
# 0  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12            31.0
# 1  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     04 TO 06            31.0
# 2  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     10 TO 12            31.0
# 3  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1     07 TO 09            31.0
# 4  ANG MO KIO    3 ROOM  216.0  ANG MO KIO AVE 1     04 TO 06            73.0
#
#        flat_model  lease_commence_date  resale_price  resale_year  \
# 0        IMPROVED                 1977        9000.0         1990
# 1        IMPROVED                 1977        6000.0         1990
# 2        IMPROVED                 1977        8000.0         1990
# 3        IMPROVED                 1977        6000.0         1990
# 4  NEW GENERATION                 1976       47200.0         1990
#
#    resale_month
# 0             1
# 1             1
# 2             1
# 3             1
# ...

# %% [markdown]
# Rearrange the features

# %%
dataframe = dataframe[['resale_year','resale_month','town','flat_type','block','street_name','storey_range','floor_area_sqm','flat_model','lease_commence_date','resale_price']]

# %%
dataframe.head(2)
# Out:
#    resale_year  resale_month        town flat_type  block       street_name  \
# 0         1990             1  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1
# 1         1990             1  ANG MO KIO    1 ROOM  309.0  ANG MO KIO AVE 1
#
#   storey_range  floor_area_sqm flat_model  lease_commence_date  resale_price
# 0     10 TO 12            31.0   IMPROVED                 1977        9000.0
# 1     04 TO 06            31.0   IMPROVED                 1977        6000.0

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 919465 entries, 0 to 921798
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   resale_year          919465 non-null  int64
#  1   resale_month         919465 non-null  int64
#  2   town                 919465 non-null  object
#  3   flat_type            919465 non-null  object
#  4   block                919465 non-null  float64
#  5   street_name          919465 non-null  object
#  6   storey_range         919465 non-null  object
#  7   floor_area_sqm       919465 non-null  float64
#  8   flat_model           919465 non-null  object
#  9   lease_commence_date  919465 non-null  int64
#  10  resale_price         919465 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 84.2+ MB

# %%
dataframe_to_csv = dataframe.to_csv('Singapore_real_estate_Cleaned.csv',index = False)

# %%
#converting the category column into numeric using label encoder
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
dataframe['town']= le1.fit_transform(dataframe['town'])
le2 = LabelEncoder()
dataframe['flat_type']= le2.fit_transform(dataframe['flat_type'])
le3 = LabelEncoder()
dataframe['street_name']= le3.fit_transform(dataframe['street_name'])
le4 = LabelEncoder()
dataframe['storey_range']= le4.fit_transform(dataframe['storey_range'])
le5 = LabelEncoder()
dataframe['flat_model']= le5.fit_transform(dataframe['flat_model'])

# %%
import pickle
pickle.dump(le1, open('label_encoder1twn.pkl', 'wb'))
pickle.dump(le2, open('label_encoder2FT.pkl', 'wb'))
pickle.dump(le3, open('label_encoder3SN.pkl', 'wb'))
pickle.dump(le4, open('label_encoder4SR.pkl', 'wb'))
pickle.dump(le5, open('label_encoder5FM.pkl', 'wb'))

# %%
category_to_check = 'Premium Apartment Loft'
le = le5
#Transform the chosen category to its encoded value
encoded_value = le.transform([category_to_check])[0]

print(f"The encoded value for '{category_to_check}' is: {encoded_value}")
# Out:
# The encoded value for 'Premium Apartment Loft' is: 24

# %% [markdown]
# **Split X and Y**

# %%
from sklearn.model_selection import train_test_split
x = dataframe.drop(['resale_year'],axis = 1)
y = dataframe['resale_year']

# %% [markdown]
# **Standardization form**

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
scaler =  StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (919465, 10)

# %%
x_scaled
# Out:
# array([[-1.62683427, -1.55125438, -3.17469519, ..., -1.30606246,
#         -1.05849593, -1.83941396],
#        [-1.62683427, -1.55125438, -3.17469519, ..., -1.30606246,
#         -1.05849593, -1.85720767],
#        [-1.62683427, -1.55125438, -3.17469519, ..., -1.30606246,
#         -1.05849593, -1.8453452 ],
#        ...,
#        [-1.04197724,  1.40399886,  2.09071285, ..., -0.10701933,
#         -0.02020719,  2.97081757],
#        [-1.04197724,  1.40399886,  2.09071285, ..., -0.10701933,
#         -0.02020719,  3.20806696],
#        [-1.04197724,  1.40399886,  2.09071285, ..., -1.60582324,
#         -0.11459707,  2.73356817]])

# %% [markdown]
# **Split train and test data**

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.2,random_state = 42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((735572, 10), (183893, 10), (735572,), (183893,))

# %% [markdown]
# **Model Selection**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
def evaluate_model(true,predicted):
  mae = mean_absolute_error(true,predicted)
  mse = mean_squared_error(true,predicted)
  rmse = np.sqrt(mean_squared_error(true,predicted))
  r2 =r2_score(true,predicted)
  return mae,mse,rmse,r2

# %%
models ={
    'LinearRegression':LinearRegression(),
    'KNeighborsRegressor':KNeighborsRegressor(),
    'DEcisionTreeRegressor':DecisionTreeRegressor(),
    'AdaBoostRegressor':AdaBoostRegressor(),
    'GradientBoostingRegressor':GradientBoostingRegressor(),
    'XGBRegressor':XGBRegressor(),
    'RandomForestRegressor':RandomForestRegressor()

}
models_list = []
for i in range(len(list(models))):
  model = list(models.values())[i]
  model.fit(x_train,y_train)

  # Make prediction
  y_train_pred = model.predict(x_train)
  y_test_pred = model.predict(x_test)

  #Training set performance
  model_train_mae,model_train_rmse,model_train_mse,model_train_r2 = evaluate_model(y_train,y_train_pred)
  model_test_mae,model_test_rmse,model_test_mse,model_test_r2_score = evaluate_model(y_test,y_test_pred)
  print(list(models.keys())[i])

  print('Model performance for Training set')
  print('- MeanAbsoluteError:{:.4f}'.format(model_train_mae))
  print('- RootMeanSquaredError:{:.4f}'.format(model_train_rmse))
  print('- MeanSquaredError:{:.4f}'.format(model_train_mse))
  print('- R2score:{:.4f}'.format(model_train_r2))

  print('------------------------------------------------------------------')
  print('Model performance for Testing set')
  print('- MeanAbsoluteError:{:.4f}'.format(model_test_mae))
  print('- RootMeanSquaredError:{:.4f}'.format(model_test_rmse))
  print('- MeanSquaredError:{:.4f}'.format(model_test_mse))
  print('- R2score:{:.4f}'.format(model_test_r2_score))

  print('='*35)
  print('\n')
# Out:
# LinearRegression
# Model performance for Training set
# - MeanAbsoluteError:4.4325
# - RootMeanSquaredError:30.9273
# - MeanSquaredError:5.5612
# - R2score:0.6384
# ------------------------------------------------------------------
# Model performance for Testing set
# - MeanAbsoluteError:4.4392
# - RootMeanSquaredError:31.0716
# - MeanSquaredError:5.5742
# - R2score:0.6360
# ...
#
#
# KNeighborsRegressor
# Model performance for Training set
# - MeanAbsoluteError:1.9589
# - RootMeanSquaredError:7.3267
# - MeanSquaredError:2.7068
# - R2score:0.9143
# ------------------------------------------------------------------
# Model performance for Testing set
# - MeanAbsoluteError:2.4635
# - RootMeanSquaredError:11.2771
# - MeanSquaredError:3.3581
# - R2score:0.8679
# ...
#
#
# DEcisionTreeRegressor
# Model performance for Training set
# - MeanAbsoluteError:0.0085
# - RootMeanSquaredError:0.0234
# - MeanSquaredError:0.1529
# - R2score:0.9997
# ...

# %% [markdown]
# In this dataset RandomForest Algorithm is the best of 92.19%
